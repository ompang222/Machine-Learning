# %% [markdown]
# <a href="https://colab.research.google.com/github/ompang222/Machine-Learning/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# 데이터를 다운로드하고 준비합니다.
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
x = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# 데이터를 그래프로 나타냅니다.
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# 선형 모델을 선택합니다.
model = LinearRegression()

# 모델을 훈련합니다.
model.fit(x, y)

# 키프로스에 대해 예측을 만듭니다.
X_new = [[37_65.2]]
print(model.predict(X_new))
# Out:
# [[4.00428856]]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

lifesat = pd.read_csv("data.csv")
X = lifesat[["dist"]].values
y = lifesat[["won"]].values

lifesat.plot(kind="scatter", grid=True, x="dist", y="won")
plt.axis([0, 12, 0, 35000])
plt.show()

model = LinearRegression()

model.fit(X, y)

X_new = [[8]]
print(model.predict(X_new))
# Out:
# [[14233.40143003]]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

lifesat = pd.read_csv("data2.csv")
X = lifesat[["waist"]].values
y = lifesat[["kg"]].values

lifesat.plot(kind="scatter", grid=True, x="waist", y="kg")
plt.axis([24, 36, 40, 90])
plt.show()

model = LinearRegression()

model.fit(X, y)

X_new = [[8]]
print(model.predict(X_new))
# Out:
# [[-11.36607143]]
